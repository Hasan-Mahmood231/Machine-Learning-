# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('zomato.csv',encoding= 'latin1')

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df_copy = df[['City','Has Table booking','Rating text','Rating color']]

# %%
df_copy.head()
# Out:
#                City Has Table booking Rating text Rating color
# 0       Makati City               Yes   Excellent   Dark Green
# 1       Makati City               Yes   Excellent   Dark Green
# 2  Mandaluyong City               Yes   Very Good        Green
# 3  Mandaluyong City                No   Excellent   Dark Green
# 4  Mandaluyong City               Yes   Excellent   Dark Green

# %%
df_copy['Rating text'].value_counts()
# Out:
# Rating text
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: count, dtype: int64

# %%
# split the df in test train
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df.drop('City',axis=1),df.iloc[:,0],random_state=42,test_size=0.2)

# %% [markdown]
# - in this data booking and rating are ordinal so we ll use ordinal encoding on them.
# - the rating_color are nominal so we ll use one hot encoding on them.

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder,OneHotEncoder
transformers = ColumnTransformer(transformers = [
    ('tn1', OrdinalEncoder(categories=[['No','Yes'],['Excellent','Very Good','Good','Average','Poor','Not rated']]),['Has Table booking','Rating text'] ),
    ('tn2', OneHotEncoder(sparse_output=False,drop='first'),['Rating color'] )
],remainder='passthrough')

# %%
tranformed = transformers.fit_transform(x_train)

# %%
tranformed.shape
# Out:
# (7640, 24)
