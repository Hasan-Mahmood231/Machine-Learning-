# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('StressLevelDataset.csv')

# %%
df.shape
# Out:
# (1100, 21)

# %%
df.head()
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
# 3               3              1                  3            4
# 4               3              5                  1            3
#
#    living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %% [markdown]
# - fsrit thing we see that categoraical data.
# - then perofom the Univeriant analysis on that data.

# %%
print(df["anxiety_level"].value_counts())
# Out:
# anxiety_level
# 13    67
# 10    63
# 19    61
# 21    61
# 9     60
# 12    56
# 18    55
# 11    54
# 6     52
# 7     51
# 14    51
# 15    51
# 3     48
# 17    47
# 1     46
# 2     46
# 16    45
# 8     44
# 5     40
# 20    40
# 4     33
# 0     29
# Name: count, dtype: int64

# %%
# categorical data.
sns.countplot(x = 'mental_health_history',data = df)
plt.show()

# %%
# Get counts of each anxiety_level
counts = df["anxiety_level"].value_counts()

# Make pie chart
plt.figure(figsize=(6,6))
plt.pie(
    counts.values,              # the counts
    labels=counts.index,        # category labels
    autopct="%1.1f%%",          # show percentages
    startangle=90               # start from top
)

plt.title("Anxiety Level Distribution")
plt.show()

# %%
df['living_conditions'].value_counts()
# Out:
# living_conditions
# 2    346
# 3    327
# 4    189
# 1    176
# 5     33
# 0     29
# Name: count, dtype: int64

# %%
df['living_conditions'].value_counts().plot(kind='pie',autopct = "%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df.head()
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
# 3               3              1                  3            4
# 4               3              5                  1            3
#
#    living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %% [markdown]
# - Now let seee the numerical data
# - And perform the univeriant analysis.

# %%
sns.histplot(df['anxiety_level'],color='orange',kde=True)
# Out:
# <Axes: xlabel='anxiety_level', ylabel='Count'>

# %%
sns.displot(df['self_esteem'])
